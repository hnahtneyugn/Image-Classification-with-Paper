# %%
import os
import glob
import math
import time
import random
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as opt
import torch.nn.functional as F
import albumentations as A
from albumentations.pytorch import ToTensorV2
from torch.utils.data import Dataset, Subset
from torchvision import transforms, datasets
from torchsummary import summary
from PIL import Image
import matplotlib.pyplot as plt
from tqdm.auto import tqdm, trange
from tqdm import tqdm, trange

# %%
seed = 42

random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)

# %%
# import kagglehub

# # Download latest version
# path = kagglehub.dataset_download("nikhilshingadiya/tinyimagenet200")

# print("Path to dataset files:", path)

# %%
import logging

# Clear existing handlers
for handler in logging.root.handlers[:]:
    logging.root.removeHandler(handler)

# Now reconfigure
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s",
    handlers=[
        logging.FileHandler("training_log.txt", mode="w")
    ]
)

# %%
train_transform = A.Compose([
    A.Resize(32, 32),
    A.PadIfNeeded(min_height=36, min_width=36, border_mode=0), 
    A.RandomCrop(32, 32),
    A.HorizontalFlip(),
    A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
    ToTensorV2()
])

val_test_transform = A.Compose([
    A.Resize(32, 32),
    A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
    ToTensorV2()
])

# %%
class TinyImageNetTrainDataset(Dataset):
    def __init__(self, train_dir, transform=None):
        self.transform = transform
        self.data = []
        self.targets = []
        self.class_to_idx = {}

        class_names = sorted(os.listdir(train_dir))
        self.class_to_idx = {cls_name: idx for idx, cls_name in enumerate(class_names)}

        for cls_name in class_names:
            cls_folder = os.path.join(train_dir, cls_name, "images")
            if not os.path.isdir(cls_folder):
                continue

            for img_file in os.listdir(cls_folder):
                if img_file.endswith('.JPEG'):
                    img_path = os.path.join(cls_folder, img_file)
                    img = Image.open(img_path).convert('RGB')
                    self.data.append(img.copy())
                    self.targets.append(self.class_to_idx[cls_name])
                    img.close()

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        img = self.data[idx]
        label = self.targets[idx]

        img = np.array(img)
        if self.transform:
            img = self.transform(image=img)['image']

        return img, label

# %%
class TinyImageNetValDataset(Dataset):
    def __init__(self, val_dir, annotations_file, transform=None):
        self.transform = transform
        self.data = []
        self.targets = []

        annotations = pd.read_csv(annotations_file, sep='\t', header=None, names=['image', 'class', 'x', 'y', 'w', 'h'])
        class_names = sorted(set(annotations['class']))
        self.class_to_idx = {class_name: i for i, class_name in enumerate(class_names)}

        for _, row in annotations.iterrows():
            img_path = os.path.join(val_dir, str(row['image']))
            img = Image.open(img_path).convert('RGB')
            self.data.append(img.copy())
            self.targets.append(self.class_to_idx[row['class']])
            img.close()

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        image = self.data[idx]
        label = self.targets[idx]
        image = np.array(image)
        if self.transform:
            image = self.transform(image=image)['image']
        return image, label

# %%
# data_dir = '/teamspace/studios/this_studio/.cache/kagglehub/datasets/nikhilshingadiya/tinyimagenet200/versions/1/tiny-imagenet-200'
data_dir = './tiny-imagenet-200'
train_dir = f'{data_dir}/newtrain'
val_dir = f'{data_dir}/val/images'
test_dir = f'{data_dir}/newtest'
annotations_file = f'{data_dir}/val/val_annotations.txt'

# %%
tinyimagenet_train = TinyImageNetTrainDataset(train_dir, transform=train_transform)
tinyimagenet_val = TinyImageNetValDataset(val_dir, annotations_file, transform=val_test_transform)
tinyimagenet_test = TinyImageNetTrainDataset(test_dir, transform=val_test_transform)

# %%
print(len(tinyimagenet_train))
print(len(tinyimagenet_val))
print(len(tinyimagenet_test))
# Out:
# 90000
# 10000
# 10000

# %%
class SEBlock(nn.Module):
    def __init__(self, channel, reduction=16):
        super(SEBlock, self).__init__()
        self.avg_pool = nn.AdaptiveAvgPool2d(1)  # Squeeze
        self.fc = nn.Sequential(
            nn.Linear(channel, channel // reduction, bias=False),
            nn.ReLU(inplace=True),
            nn.Linear(channel // reduction, channel, bias=False),
            nn.Sigmoid()
        )

    def forward(self, x):
        b, c, _, _ = x.size()
        y = self.avg_pool(x).view(b, c)  # Squeeze
        y = self.fc(y).view(b, c, 1, 1)  # Excitation
        return x * y.expand_as(x)  # Scale

# %%
class Bottleneck(nn.Module):
    def __init__(self, in_channels, growthRate, reduction=16):
        super(Bottleneck, self).__init__()
        inter_channels = 4 * growthRate
        self.dropout1 = nn.Dropout2d(0.2)
        self.bn1 = nn.BatchNorm2d(in_channels)
        self.conv1 = nn.Conv2d(in_channels, inter_channels, kernel_size=1, bias=False)
        self.dropout2 = nn.Dropout2d(0.2)
        self.bn2 = nn.BatchNorm2d(inter_channels)
        self.conv2 = nn.Conv2d(inter_channels, growthRate, kernel_size=3, padding=1, bias=False)
        self.se = SEBlock(growthRate, reduction)
    
    def forward(self, x):
        y = self.dropout1(x)
        y = self.conv1(F.relu(self.bn1(y)))
        y = self.dropout2(y)
        y = self.conv2(F.relu(self.bn2(y)))
        y = self.se(y)
        return y

# %%
class DenseBlock(nn.Module):
    def __init__(self, in_channels, growthRate, nums_bottleneck):
        super(DenseBlock, self).__init__()
        layers = []
        for i in range(nums_bottleneck):
            layers.append(Bottleneck(in_channels=in_channels, growthRate=growthRate, reduction=16))
            in_channels += growthRate
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        for layer in self.net:
            y = layer(x)
            x = torch.cat((x, y), dim=1)
        return x

# %%
class TransitionLayer(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(TransitionLayer, self).__init__()
        self.bn1 = nn.BatchNorm2d(in_channels)
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=1, bias=False)
    
    def forward(self, x):
        y = self.conv1(F.relu(self.bn1(x)))
        y = F.avg_pool2d(y, kernel_size=2, stride=2)
        return y

# %%
class Net(nn.Module):
    def __init__(self, depth, growthRate, compression_factor, num_classes):
        super(Net, self).__init__()
        nums_bottleneck = (depth - 4) // 3 // 2      # (100 - 4) // 3 // 2 = 16  
        out_channels = 2 * growthRate    # Initialize out_channels

        self.initial_layer = nn.Conv2d(3, out_channels, kernel_size=3, padding=1, bias=False)       # Shape: (3, 32, 32) -> (24, 32, 32)

        self.dense_block_1 = DenseBlock(in_channels=out_channels, growthRate=growthRate, nums_bottleneck=nums_bottleneck)   # Shape: (24, 32, 32) -> (216, 32, 32)
        out_channels += growthRate * nums_bottleneck    # Update out_channels from 24 -> 216
        halved_channels = int(math.floor(out_channels * compression_factor))     # Halved_channels = 108
        self.transition_layer_1 = TransitionLayer(in_channels=out_channels, out_channels=halved_channels)       # Shape: (216, 32, 32) -> (108, 16, 16)

        out_channels = halved_channels      # Update out_channels from 216 -> 108

        self.dense_block_2 = DenseBlock(in_channels=out_channels, growthRate=growthRate, nums_bottleneck=nums_bottleneck)   # Shape: (108, 16, 16) -> (300, 16, 16)
        out_channels += growthRate * nums_bottleneck    # Update out_channels from 108 -> 300
        halved_channels = int(math.floor(out_channels * compression_factor))     # Halved_channels = 150
        self.transition_layer_2 = TransitionLayer(in_channels=out_channels, out_channels=halved_channels)       # Shape: (300, 16, 16)  -> (150, 8, 8)

        out_channels = halved_channels      # Update out_channels from 300 -> 150
    
        self.dense_block_3 = DenseBlock(in_channels=out_channels, growthRate=growthRate, nums_bottleneck=nums_bottleneck)   # Shape: (150, 8, 8) -> (342, 8, 8)
        out_channels += growthRate * nums_bottleneck    # Update out_channels 150 -> 342

        self.bn = nn.BatchNorm2d(out_channels)
        self.avg = nn.AdaptiveAvgPool2d((1, 1))     # Shape: (342, 8, 8) -> (342, 1, 1)
        self.flattener = nn.Flatten()               # Shape: (342, 1, 1) -> (342)
        self.classifier = nn.Linear(out_channels, num_classes)   # Shape: (342) -> (100)
    
    def forward(self, x):
        x = self.initial_layer(x)
        x = self.transition_layer_1(self.dense_block_1(x))
        x = self.transition_layer_2(self.dense_block_2(x))
        x = self.dense_block_3(x)
        x = F.relu(self.bn(x))
        x = self.avg(x)
        x = self.flattener(x)
        x = self.classifier(x)
        return x

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
print(torch.cuda.get_device_name())
# Out:
# cuda
# NVIDIA GeForce RTX 3060

# %%
# L = 100, k = 12, theta = 0.5, 10 classes to classify
net = Net(depth=100, growthRate=12, compression_factor=0.5, num_classes=200).to(device)
summary(net, input_size=(3, 64, 64))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 24, 64, 64]             648
#          Dropout2d-2           [-1, 24, 64, 64]               0
#        BatchNorm2d-3           [-1, 24, 64, 64]              48
#             Conv2d-4           [-1, 48, 64, 64]           1,152
#          Dropout2d-5           [-1, 48, 64, 64]               0
#        BatchNorm2d-6           [-1, 48, 64, 64]              96
#             Conv2d-7           [-1, 12, 64, 64]           5,184
#  AdaptiveAvgPool2d-8             [-1, 12, 1, 1]               0
#             Linear-9                    [-1, 0]               0
#              ReLU-10                    [-1, 0]               0
#            Linear-11                   [-1, 12]               0
#           Sigmoid-12                   [-1, 12]               0
#           SEBlock-13           [-1, 12, 64, 64]               0
#        Bottleneck-14           [-1, 12, 64, 64]               0
#         Dropout2d-15           [-1, 36, 64, 64]               0
#       BatchNorm2d-16           [-1, 36, 64, 64]              72
#            Conv2d-17           [-1, 48, 64, 64]           1,728
#         Dropout2d-18           [-1, 48, 64, 64]               0
#       BatchNorm2d-19           [-1, 48, 64, 64]              96
#            Conv2d-20           [-1, 12, 64, 64]           5,184
# AdaptiveAvgPool2d-21             [-1, 12, 1, 1]               0
#            Linear-22                    [-1, 0]               0
#              ReLU-23                    [-1, 0]               0
#            Linear-24                   [-1, 12]               0
#           Sigmoid-25                   [-1, 12]               0
#           SEBlock-26           [-1, 12, 64, 64]               0
#        Bottleneck-27           [-1, 12, 64, 64]               0
#         Dropout2d-28           [-1, 48, 64, 64]               0
#       BatchNorm2d-29           [-1, 48, 64, 64]              96
#            Conv2d-30           [-1, 48, 64, 64]           2,304
#         Dropout2d-31           [-1, 48, 64, 64]               0
#       BatchNorm2d-32           [-1, 48, 64, 64]              96
#            Conv2d-33           [-1, 12, 64, 64]           5,184
# AdaptiveAvgPool2d-34             [-1, 12, 1, 1]               0
#            Linear-35                    [-1, 0]               0
#              ReLU-36                    [-1, 0]               0
#            Linear-37                   [-1, 12]               0
#           Sigmoid-38                   [-1, 12]               0
#           SEBlock-39           [-1, 12, 64, 64]               0
#        Bottleneck-40           [-1, 12, 64, 64]               0
#         Dropout2d-41           [-1, 60, 64, 64]               0
#       BatchNorm2d-42           [-1, 60, 64, 64]             120
#            Conv2d-43           [-1, 48, 64, 64]           2,880
#         Dropout2d-44           [-1, 48, 64, 64]               0
#       BatchNorm2d-45           [-1, 48, 64, 64]              96
#            Conv2d-46           [-1, 12, 64, 64]           5,184
# AdaptiveAvgPool2d-47             [-1, 12, 1, 1]               0
#            Linear-48                    [-1, 0]               0
#              ReLU-49                    [-1, 0]               0
#            Linear-50                   [-1, 12]               0
#           Sigmoid-51                   [-1, 12]               0
#           SEBlock-52           [-1, 12, 64, 64]               0
#        Bottleneck-53           [-1, 12, 64, 64]               0
#         Dropout2d-54           [-1, 72, 64, 64]               0
#       BatchNorm2d-55           [-1, 72, 64, 64]             144
#            Conv2d-56           [-1, 48, 64, 64]           3,456
#         Dropout2d-57           [-1, 48, 64, 64]               0
#       BatchNorm2d-58           [-1, 48, 64, 64]              96
#            Conv2d-59           [-1, 12, 64, 64]           5,184
# AdaptiveAvgPool2d-60             [-1, 12, 1, 1]               0
#            Linear-61                    [-1, 0]               0
#              ReLU-62                    [-1, 0]               0
#            Linear-63                   [-1, 12]               0
#           Sigmoid-64                   [-1, 12]               0
#           SEBlock-65           [-1, 12, 64, 64]               0
#        Bottleneck-66           [-1, 12, 64, 64]               0
#         Dropout2d-67           [-1, 84, 64, 64]               0
#       BatchNorm2d-68           [-1, 84, 64, 64]             168
#            Conv2d-69           [-1, 48, 64, 64]           4,032
#         Dropout2d-70           [-1, 48, 64, 64]               0
#       BatchNorm2d-71           [-1, 48, 64, 64]              96
#            Conv2d-72           [-1, 12, 64, 64]           5,184
# AdaptiveAvgPool2d-73             [-1, 12, 1, 1]               0
#            Linear-74                    [-1, 0]               0
#              ReLU-75                    [-1, 0]               0
#            Linear-76                   [-1, 12]               0
#           Sigmoid-77                   [-1, 12]               0
#           SEBlock-78           [-1, 12, 64, 64]               0
#        Bottleneck-79           [-1, 12, 64, 64]               0
#         Dropout2d-80           [-1, 96, 64, 64]               0
#       BatchNorm2d-81           [-1, 96, 64, 64]             192
#            Conv2d-82           [-1, 48, 64, 64]           4,608
#         Dropout2d-83           [-1, 48, 64, 64]               0
#       BatchNorm2d-84           [-1, 48, 64, 64]              96
#            Conv2d-85           [-1, 12, 64, 64]           5,184
# AdaptiveAvgPool2d-86             [-1, 12, 1, 1]               0
#            Linear-87                    [-1, 0]               0
#              ReLU-88                    [-1, 0]               0
#            Linear-89                   [-1, 12]               0
#           Sigmoid-90                   [-1, 12]               0
#           SEBlock-91           [-1, 12, 64, 64]               0
#        Bottleneck-92           [-1, 12, 64, 64]               0
#         Dropout2d-93          [-1, 108, 64, 64]               0
#       BatchNorm2d-94          [-1, 108, 64, 64]             216
#            Conv2d-95           [-1, 48, 64, 64]           5,184
#         Dropout2d-96           [-1, 48, 64, 64]               0
#       BatchNorm2d-97           [-1, 48, 64, 64]              96
#            Conv2d-98           [-1, 12, 64, 64]           5,184
# AdaptiveAvgPool2d-99             [-1, 12, 1, 1]               0
#           Linear-100                    [-1, 0]               0
#             ReLU-101                    [-1, 0]               0
#           Linear-102                   [-1, 12]               0
#          Sigmoid-103                   [-1, 12]               0
#          SEBlock-104           [-1, 12, 64, 64]               0
#       Bottleneck-105           [-1, 12, 64, 64]               0
#        Dropout2d-106          [-1, 120, 64, 64]               0
#      BatchNorm2d-107          [-1, 120, 64, 64]             240
#           Conv2d-108           [-1, 48, 64, 64]           5,760
#        Dropout2d-109           [-1, 48, 64, 64]               0
#      BatchNorm2d-110           [-1, 48, 64, 64]              96
#           Conv2d-111           [-1, 12, 64, 64]           5,184
# AdaptiveAvgPool2d-112             [-1, 12, 1, 1]               0
#           Linear-113                    [-1, 0]               0
#             ReLU-114                    [-1, 0]               0
#           Linear-115                   [-1, 12]               0
#          Sigmoid-116                   [-1, 12]               0
#          SEBlock-117           [-1, 12, 64, 64]               0
#       Bottleneck-118           [-1, 12, 64, 64]               0
#        Dropout2d-119          [-1, 132, 64, 64]               0
#      BatchNorm2d-120          [-1, 132, 64, 64]             264
#           Conv2d-121           [-1, 48, 64, 64]           6,336
#        Dropout2d-122           [-1, 48, 64, 64]               0
#      BatchNorm2d-123           [-1, 48, 64, 64]              96
#           Conv2d-124           [-1, 12, 64, 64]           5,184
# AdaptiveAvgPool2d-125             [-1, 12, 1, 1]               0
#           Linear-126                    [-1, 0]               0
#             ReLU-127                    [-1, 0]               0
#           Linear-128                   [-1, 12]               0
#          Sigmoid-129                   [-1, 12]               0
#          SEBlock-130           [-1, 12, 64, 64]               0
#       Bottleneck-131           [-1, 12, 64, 64]               0
#        Dropout2d-132          [-1, 144, 64, 64]               0
#      BatchNorm2d-133          [-1, 144, 64, 64]             288
#           Conv2d-134           [-1, 48, 64, 64]           6,912
#        Dropout2d-135           [-1, 48, 64, 64]               0
#      BatchNorm2d-136           [-1, 48, 64, 64]              96
#           Conv2d-137           [-1, 12, 64, 64]           5,184
# AdaptiveAvgPool2d-138             [-1, 12, 1, 1]               0
#           Linear-139                    [-1, 0]               0
#             ReLU-140                    [-1, 0]               0
#           Linear-141                   [-1, 12]               0
#          Sigmoid-142                   [-1, 12]               0
#          SEBlock-143           [-1, 12, 64, 64]               0
#       Bottleneck-144           [-1, 12, 64, 64]               0
#        Dropout2d-145          [-1, 156, 64, 64]               0
#      BatchNorm2d-146          [-1, 156, 64, 64]             312
#           Conv2d-147           [-1, 48, 64, 64]           7,488
#        Dropout2d-148           [-1, 48, 64, 64]               0
#      BatchNorm2d-149           [-1, 48, 64, 64]              96
#           Conv2d-150           [-1, 12, 64, 64]           5,184
# AdaptiveAvgPool2d-151             [-1, 12, 1, 1]               0
#           Linear-152                    [-1, 0]               0
#             ReLU-153                    [-1, 0]               0
#           Linear-154                   [-1, 12]               0
#          Sigmoid-155                   [-1, 12]               0
#          SEBlock-156           [-1, 12, 64, 64]               0
#       Bottleneck-157           [-1, 12, 64, 64]               0
#        Dropout2d-158          [-1, 168, 64, 64]               0
#      BatchNorm2d-159          [-1, 168, 64, 64]             336
#           Conv2d-160           [-1, 48, 64, 64]           8,064
#        Dropout2d-161           [-1, 48, 64, 64]               0
#      BatchNorm2d-162           [-1, 48, 64, 64]              96
#           Conv2d-163           [-1, 12, 64, 64]           5,184
# AdaptiveAvgPool2d-164             [-1, 12, 1, 1]               0
#           Linear-165                    [-1, 0]               0
#             ReLU-166                    [-1, 0]               0
#           Linear-167                   [-1, 12]               0
#          Sigmoid-168                   [-1, 12]               0
#          SEBlock-169           [-1, 12, 64, 64]               0
#       Bottleneck-170           [-1, 12, 64, 64]               0
#        Dropout2d-171          [-1, 180, 64, 64]               0
#      BatchNorm2d-172          [-1, 180, 64, 64]             360
#           Conv2d-173           [-1, 48, 64, 64]           8,640
#        Dropout2d-174           [-1, 48, 64, 64]               0
#      BatchNorm2d-175           [-1, 48, 64, 64]              96
#           Conv2d-176           [-1, 12, 64, 64]           5,184
# AdaptiveAvgPool2d-177             [-1, 12, 1, 1]               0
#           Linear-178                    [-1, 0]               0
#             ReLU-179                    [-1, 0]               0
#           Linear-180                   [-1, 12]               0
#          Sigmoid-181                   [-1, 12]               0
#          SEBlock-182           [-1, 12, 64, 64]               0
#       Bottleneck-183           [-1, 12, 64, 64]               0
#        Dropout2d-184          [-1, 192, 64, 64]               0
#      BatchNorm2d-185          [-1, 192, 64, 64]             384
#           Conv2d-186           [-1, 48, 64, 64]           9,216
#        Dropout2d-187           [-1, 48, 64, 64]               0
#      BatchNorm2d-188           [-1, 48, 64, 64]              96
#           Conv2d-189           [-1, 12, 64, 64]           5,184
# AdaptiveAvgPool2d-190             [-1, 12, 1, 1]               0
#           Linear-191                    [-1, 0]               0
#             ReLU-192                    [-1, 0]               0
#           Linear-193                   [-1, 12]               0
#          Sigmoid-194                   [-1, 12]               0
#          SEBlock-195           [-1, 12, 64, 64]               0
#       Bottleneck-196           [-1, 12, 64, 64]               0
#        Dropout2d-197          [-1, 204, 64, 64]               0
#      BatchNorm2d-198          [-1, 204, 64, 64]             408
#           Conv2d-199           [-1, 48, 64, 64]           9,792
#        Dropout2d-200           [-1, 48, 64, 64]               0
#      BatchNorm2d-201           [-1, 48, 64, 64]              96
#           Conv2d-202           [-1, 12, 64, 64]           5,184
# AdaptiveAvgPool2d-203             [-1, 12, 1, 1]               0
#           Linear-204                    [-1, 0]               0
#             ReLU-205                    [-1, 0]               0
#           Linear-206                   [-1, 12]               0
#          Sigmoid-207                   [-1, 12]               0
#          SEBlock-208           [-1, 12, 64, 64]               0
#       Bottleneck-209           [-1, 12, 64, 64]               0
#       DenseBlock-210          [-1, 216, 64, 64]               0
#      BatchNorm2d-211          [-1, 216, 64, 64]             432
#           Conv2d-212          [-1, 108, 64, 64]          23,328
#  TransitionLayer-213          [-1, 108, 32, 32]               0
#        Dropout2d-214          [-1, 108, 32, 32]               0
#      BatchNorm2d-215          [-1, 108, 32, 32]             216
#           Conv2d-216           [-1, 48, 32, 32]           5,184
#        Dropout2d-217           [-1, 48, 32, 32]               0
#      BatchNorm2d-218           [-1, 48, 32, 32]              96
#           Conv2d-219           [-1, 12, 32, 32]           5,184
# AdaptiveAvgPool2d-220             [-1, 12, 1, 1]               0
#           Linear-221                    [-1, 0]               0
#             ReLU-222                    [-1, 0]               0
#           Linear-223                   [-1, 12]               0
#          Sigmoid-224                   [-1, 12]               0
#          SEBlock-225           [-1, 12, 32, 32]               0
#       Bottleneck-226           [-1, 12, 32, 32]               0
#        Dropout2d-227          [-1, 120, 32, 32]               0
#      BatchNorm2d-228          [-1, 120, 32, 32]             240
#           Conv2d-229           [-1, 48, 32, 32]           5,760
#        Dropout2d-230           [-1, 48, 32, 32]               0
#      BatchNorm2d-231           [-1, 48, 32, 32]              96
#           Conv2d-232           [-1, 12, 32, 32]           5,184
# AdaptiveAvgPool2d-233             [-1, 12, 1, 1]               0
#           Linear-234                    [-1, 0]               0
#             ReLU-235                    [-1, 0]               0
#           Linear-236                   [-1, 12]               0
#          Sigmoid-237                   [-1, 12]               0
#          SEBlock-238           [-1, 12, 32, 32]               0
#       Bottleneck-239           [-1, 12, 32, 32]               0
#        Dropout2d-240          [-1, 132, 32, 32]               0
#      BatchNorm2d-241          [-1, 132, 32, 32]             264
#           Conv2d-242           [-1, 48, 32, 32]           6,336
#        Dropout2d-243           [-1, 48, 32, 32]               0
#      BatchNorm2d-244           [-1, 48, 32, 32]              96
#           Conv2d-245           [-1, 12, 32, 32]           5,184
# AdaptiveAvgPool2d-246             [-1, 12, 1, 1]               0
#           Linear-247                    [-1, 0]               0
#             ReLU-248                    [-1, 0]               0
#           Linear-249                   [-1, 12]               0
#          Sigmoid-250                   [-1, 12]               0
#          SEBlock-251           [-1, 12, 32, 32]               0
#       Bottleneck-252           [-1, 12, 32, 32]               0
#        Dropout2d-253          [-1, 144, 32, 32]               0
#      BatchNorm2d-254          [-1, 144, 32, 32]             288
#           Conv2d-255           [-1, 48, 32, 32]           6,912
#        Dropout2d-256           [-1, 48, 32, 32]               0
#      BatchNorm2d-257           [-1, 48, 32, 32]              96
#           Conv2d-258           [-1, 12, 32, 32]           5,184
# AdaptiveAvgPool2d-259             [-1, 12, 1, 1]               0
#           Linear-260                    [-1, 0]               0
#             ReLU-261                    [-1, 0]               0
#           Linear-262                   [-1, 12]               0
#          Sigmoid-263                   [-1, 12]               0
#          SEBlock-264           [-1, 12, 32, 32]               0
#       Bottleneck-265           [-1, 12, 32, 32]               0
#        Dropout2d-266          [-1, 156, 32, 32]               0
#      BatchNorm2d-267          [-1, 156, 32, 32]             312
#           Conv2d-268           [-1, 48, 32, 32]           7,488
#        Dropout2d-269           [-1, 48, 32, 32]               0
#      BatchNorm2d-270           [-1, 48, 32, 32]              96
#           Conv2d-271           [-1, 12, 32, 32]           5,184
# AdaptiveAvgPool2d-272             [-1, 12, 1, 1]               0
#           Linear-273                    [-1, 0]               0
#             ReLU-274                    [-1, 0]               0
#           Linear-275                   [-1, 12]               0
#          Sigmoid-276                   [-1, 12]               0
#          SEBlock-277           [-1, 12, 32, 32]               0
#       Bottleneck-278           [-1, 12, 32, 32]               0
#        Dropout2d-279          [-1, 168, 32, 32]               0
#      BatchNorm2d-280          [-1, 168, 32, 32]             336
#           Conv2d-281           [-1, 48, 32, 32]           8,064
#        Dropout2d-282           [-1, 48, 32, 32]               0
#      BatchNorm2d-283           [-1, 48, 32, 32]              96
#           Conv2d-284           [-1, 12, 32, 32]           5,184
# AdaptiveAvgPool2d-285             [-1, 12, 1, 1]               0
#           Linear-286                    [-1, 0]               0
#             ReLU-287                    [-1, 0]               0
#           Linear-288                   [-1, 12]               0
#          Sigmoid-289                   [-1, 12]               0
#          SEBlock-290           [-1, 12, 32, 32]               0
#       Bottleneck-291           [-1, 12, 32, 32]               0
#        Dropout2d-292          [-1, 180, 32, 32]               0
#      BatchNorm2d-293          [-1, 180, 32, 32]             360
#           Conv2d-294           [-1, 48, 32, 32]           8,640
#        Dropout2d-295           [-1, 48, 32, 32]               0
#      BatchNorm2d-296           [-1, 48, 32, 32]              96
#           Conv2d-297           [-1, 12, 32, 32]           5,184
# AdaptiveAvgPool2d-298             [-1, 12, 1, 1]               0
#           Linear-299                    [-1, 0]               0
#             ReLU-300                    [-1, 0]               0
#           Linear-301                   [-1, 12]               0
#          Sigmoid-302                   [-1, 12]               0
#          SEBlock-303           [-1, 12, 32, 32]               0
#       Bottleneck-304           [-1, 12, 32, 32]               0
#        Dropout2d-305          [-1, 192, 32, 32]               0
#      BatchNorm2d-306          [-1, 192, 32, 32]             384
#           Conv2d-307           [-1, 48, 32, 32]           9,216
#        Dropout2d-308           [-1, 48, 32, 32]               0
#      BatchNorm2d-309           [-1, 48, 32, 32]              96
#           Conv2d-310           [-1, 12, 32, 32]           5,184
# AdaptiveAvgPool2d-311             [-1, 12, 1, 1]               0
#           Linear-312                    [-1, 0]               0
#             ReLU-313                    [-1, 0]               0
#           Linear-314                   [-1, 12]               0
#          Sigmoid-315                   [-1, 12]               0
#          SEBlock-316           [-1, 12, 32, 32]               0
#       Bottleneck-317           [-1, 12, 32, 32]               0
#        Dropout2d-318          [-1, 204, 32, 32]               0
#      BatchNorm2d-319          [-1, 204, 32, 32]             408
#           Conv2d-320           [-1, 48, 32, 32]           9,792
#        Dropout2d-321           [-1, 48, 32, 32]               0
#      BatchNorm2d-322           [-1, 48, 32, 32]              96
#           Conv2d-323           [-1, 12, 32, 32]           5,184
# AdaptiveAvgPool2d-324             [-1, 12, 1, 1]               0
#           Linear-325                    [-1, 0]               0
#             ReLU-326                    [-1, 0]               0
#           Linear-327                   [-1, 12]               0
#          Sigmoid-328                   [-1, 12]               0
#          SEBlock-329           [-1, 12, 32, 32]               0
#       Bottleneck-330           [-1, 12, 32, 32]               0
#        Dropout2d-331          [-1, 216, 32, 32]               0
#      BatchNorm2d-332          [-1, 216, 32, 32]             432
#           Conv2d-333           [-1, 48, 32, 32]          10,368
#        Dropout2d-334           [-1, 48, 32, 32]               0
#      BatchNorm2d-335           [-1, 48, 32, 32]              96
#           Conv2d-336           [-1, 12, 32, 32]           5,184
# AdaptiveAvgPool2d-337             [-1, 12, 1, 1]               0
#           Linear-338                    [-1, 0]               0
#             ReLU-339                    [-1, 0]               0
#           Linear-340                   [-1, 12]               0
#          Sigmoid-341                   [-1, 12]               0
#          SEBlock-342           [-1, 12, 32, 32]               0
#       Bottleneck-343           [-1, 12, 32, 32]               0
#        Dropout2d-344          [-1, 228, 32, 32]               0
#      BatchNorm2d-345          [-1, 228, 32, 32]             456
#           Conv2d-346           [-1, 48, 32, 32]          10,944
#        Dropout2d-347           [-1, 48, 32, 32]               0
#      BatchNorm2d-348           [-1, 48, 32, 32]              96
#           Conv2d-349           [-1, 12, 32, 32]           5,184
# AdaptiveAvgPool2d-350             [-1, 12, 1, 1]               0
#           Linear-351                    [-1, 0]               0
#             ReLU-352                    [-1, 0]               0
#           Linear-353                   [-1, 12]               0
#          Sigmoid-354                   [-1, 12]               0
#          SEBlock-355           [-1, 12, 32, 32]               0
#       Bottleneck-356           [-1, 12, 32, 32]               0
#        Dropout2d-357          [-1, 240, 32, 32]               0
#      BatchNorm2d-358          [-1, 240, 32, 32]             480
#           Conv2d-359           [-1, 48, 32, 32]          11,520
#        Dropout2d-360           [-1, 48, 32, 32]               0
#      BatchNorm2d-361           [-1, 48, 32, 32]              96
#           Conv2d-362           [-1, 12, 32, 32]           5,184
# AdaptiveAvgPool2d-363             [-1, 12, 1, 1]               0
#           Linear-364                    [-1, 0]               0
#             ReLU-365                    [-1, 0]               0
#           Linear-366                   [-1, 12]               0
#          Sigmoid-367                   [-1, 12]               0
#          SEBlock-368           [-1, 12, 32, 32]               0
#       Bottleneck-369           [-1, 12, 32, 32]               0
#        Dropout2d-370          [-1, 252, 32, 32]               0
#      BatchNorm2d-371          [-1, 252, 32, 32]             504
#           Conv2d-372           [-1, 48, 32, 32]          12,096
#        Dropout2d-373           [-1, 48, 32, 32]               0
#      BatchNorm2d-374           [-1, 48, 32, 32]              96
#           Conv2d-375           [-1, 12, 32, 32]           5,184
# AdaptiveAvgPool2d-376             [-1, 12, 1, 1]               0
#           Linear-377                    [-1, 0]               0
#             ReLU-378                    [-1, 0]               0
#           Linear-379                   [-1, 12]               0
#          Sigmoid-380                   [-1, 12]               0
#          SEBlock-381           [-1, 12, 32, 32]               0
#       Bottleneck-382           [-1, 12, 32, 32]               0
#        Dropout2d-383          [-1, 264, 32, 32]               0
#      BatchNorm2d-384          [-1, 264, 32, 32]             528
#           Conv2d-385           [-1, 48, 32, 32]          12,672
#        Dropout2d-386           [-1, 48, 32, 32]               0
#      BatchNorm2d-387           [-1, 48, 32, 32]              96
#           Conv2d-388           [-1, 12, 32, 32]           5,184
# AdaptiveAvgPool2d-389             [-1, 12, 1, 1]               0
#           Linear-390                    [-1, 0]               0
#             ReLU-391                    [-1, 0]               0
#           Linear-392                   [-1, 12]               0
#          Sigmoid-393                   [-1, 12]               0
#          SEBlock-394           [-1, 12, 32, 32]               0
#       Bottleneck-395           [-1, 12, 32, 32]               0
#        Dropout2d-396          [-1, 276, 32, 32]               0
#      BatchNorm2d-397          [-1, 276, 32, 32]             552
#           Conv2d-398           [-1, 48, 32, 32]          13,248
#        Dropout2d-399           [-1, 48, 32, 32]               0
#      BatchNorm2d-400           [-1, 48, 32, 32]              96
#           Conv2d-401           [-1, 12, 32, 32]           5,184
# AdaptiveAvgPool2d-402             [-1, 12, 1, 1]               0
#           Linear-403                    [-1, 0]               0
#             ReLU-404                    [-1, 0]               0
#           Linear-405                   [-1, 12]               0
#          Sigmoid-406                   [-1, 12]               0
#          SEBlock-407           [-1, 12, 32, 32]               0
#       Bottleneck-408           [-1, 12, 32, 32]               0
#        Dropout2d-409          [-1, 288, 32, 32]               0
#      BatchNorm2d-410          [-1, 288, 32, 32]             576
#           Conv2d-411           [-1, 48, 32, 32]          13,824
#        Dropout2d-412           [-1, 48, 32, 32]               0
#      BatchNorm2d-413           [-1, 48, 32, 32]              96
#           Conv2d-414           [-1, 12, 32, 32]           5,184
# AdaptiveAvgPool2d-415             [-1, 12, 1, 1]               0
#           Linear-416                    [-1, 0]               0
#             ReLU-417                    [-1, 0]               0
#           Linear-418                   [-1, 12]               0
#          Sigmoid-419                   [-1, 12]               0
#          SEBlock-420           [-1, 12, 32, 32]               0
#       Bottleneck-421           [-1, 12, 32, 32]               0
#       DenseBlock-422          [-1, 300, 32, 32]               0
#      BatchNorm2d-423          [-1, 300, 32, 32]             600
#           Conv2d-424          [-1, 150, 32, 32]          45,000
#  TransitionLayer-425          [-1, 150, 16, 16]               0
#        Dropout2d-426          [-1, 150, 16, 16]               0
#      BatchNorm2d-427          [-1, 150, 16, 16]             300
#           Conv2d-428           [-1, 48, 16, 16]           7,200
#        Dropout2d-429           [-1, 48, 16, 16]               0
#      BatchNorm2d-430           [-1, 48, 16, 16]              96
#           Conv2d-431           [-1, 12, 16, 16]           5,184
# AdaptiveAvgPool2d-432             [-1, 12, 1, 1]               0
#           Linear-433                    [-1, 0]               0
#             ReLU-434                    [-1, 0]               0
#           Linear-435                   [-1, 12]               0
#          Sigmoid-436                   [-1, 12]               0
#          SEBlock-437           [-1, 12, 16, 16]               0
#       Bottleneck-438           [-1, 12, 16, 16]               0
#        Dropout2d-439          [-1, 162, 16, 16]               0
#      BatchNorm2d-440          [-1, 162, 16, 16]             324
#           Conv2d-441           [-1, 48, 16, 16]           7,776
#        Dropout2d-442           [-1, 48, 16, 16]               0
#      BatchNorm2d-443           [-1, 48, 16, 16]              96
#           Conv2d-444           [-1, 12, 16, 16]           5,184
# AdaptiveAvgPool2d-445             [-1, 12, 1, 1]               0
#           Linear-446                    [-1, 0]               0
#             ReLU-447                    [-1, 0]               0
#           Linear-448                   [-1, 12]               0
#          Sigmoid-449                   [-1, 12]               0
#          SEBlock-450           [-1, 12, 16, 16]               0
#       Bottleneck-451           [-1, 12, 16, 16]               0
#        Dropout2d-452          [-1, 174, 16, 16]               0
#      BatchNorm2d-453          [-1, 174, 16, 16]             348
#           Conv2d-454           [-1, 48, 16, 16]           8,352
#        Dropout2d-455           [-1, 48, 16, 16]               0
#      BatchNorm2d-456           [-1, 48, 16, 16]              96
#           Conv2d-457           [-1, 12, 16, 16]           5,184
# AdaptiveAvgPool2d-458             [-1, 12, 1, 1]               0
#           Linear-459                    [-1, 0]               0
#             ReLU-460                    [-1, 0]               0
#           Linear-461                   [-1, 12]               0
#          Sigmoid-462                   [-1, 12]               0
#          SEBlock-463           [-1, 12, 16, 16]               0
#       Bottleneck-464           [-1, 12, 16, 16]               0
#        Dropout2d-465          [-1, 186, 16, 16]               0
#      BatchNorm2d-466          [-1, 186, 16, 16]             372
#           Conv2d-467           [-1, 48, 16, 16]           8,928
#        Dropout2d-468           [-1, 48, 16, 16]               0
#      BatchNorm2d-469           [-1, 48, 16, 16]              96
#           Conv2d-470           [-1, 12, 16, 16]           5,184
# AdaptiveAvgPool2d-471             [-1, 12, 1, 1]               0
#           Linear-472                    [-1, 0]               0
#             ReLU-473                    [-1, 0]               0
#           Linear-474                   [-1, 12]               0
#          Sigmoid-475                   [-1, 12]               0
#          SEBlock-476           [-1, 12, 16, 16]               0
#       Bottleneck-477           [-1, 12, 16, 16]               0
#        Dropout2d-478          [-1, 198, 16, 16]               0
#      BatchNorm2d-479          [-1, 198, 16, 16]             396
#           Conv2d-480           [-1, 48, 16, 16]           9,504
#        Dropout2d-481           [-1, 48, 16, 16]               0
#      BatchNorm2d-482           [-1, 48, 16, 16]              96
#           Conv2d-483           [-1, 12, 16, 16]           5,184
# AdaptiveAvgPool2d-484             [-1, 12, 1, 1]               0
#           Linear-485                    [-1, 0]               0
#             ReLU-486                    [-1, 0]               0
#           Linear-487                   [-1, 12]               0
#          Sigmoid-488                   [-1, 12]               0
#          SEBlock-489           [-1, 12, 16, 16]               0
#       Bottleneck-490           [-1, 12, 16, 16]               0
#        Dropout2d-491          [-1, 210, 16, 16]               0
#      BatchNorm2d-492          [-1, 210, 16, 16]             420
#           Conv2d-493           [-1, 48, 16, 16]          10,080
#        Dropout2d-494           [-1, 48, 16, 16]               0
#      BatchNorm2d-495           [-1, 48, 16, 16]              96
#           Conv2d-496           [-1, 12, 16, 16]           5,184
# AdaptiveAvgPool2d-497             [-1, 12, 1, 1]               0
#           Linear-498                    [-1, 0]               0
#             ReLU-499                    [-1, 0]               0
#           Linear-500                   [-1, 12]               0
#          Sigmoid-501                   [-1, 12]               0
#          SEBlock-502           [-1, 12, 16, 16]               0
#       Bottleneck-503           [-1, 12, 16, 16]               0
#        Dropout2d-504          [-1, 222, 16, 16]               0
#      BatchNorm2d-505          [-1, 222, 16, 16]             444
#           Conv2d-506           [-1, 48, 16, 16]          10,656
#        Dropout2d-507           [-1, 48, 16, 16]               0
#      BatchNorm2d-508           [-1, 48, 16, 16]              96
#           Conv2d-509           [-1, 12, 16, 16]           5,184
# AdaptiveAvgPool2d-510             [-1, 12, 1, 1]               0
#           Linear-511                    [-1, 0]               0
#             ReLU-512                    [-1, 0]               0
#           Linear-513                   [-1, 12]               0
#          Sigmoid-514                   [-1, 12]               0
#          SEBlock-515           [-1, 12, 16, 16]               0
#       Bottleneck-516           [-1, 12, 16, 16]               0
#        Dropout2d-517          [-1, 234, 16, 16]               0
#      BatchNorm2d-518          [-1, 234, 16, 16]             468
#           Conv2d-519           [-1, 48, 16, 16]          11,232
#        Dropout2d-520           [-1, 48, 16, 16]               0
#      BatchNorm2d-521           [-1, 48, 16, 16]              96
#           Conv2d-522           [-1, 12, 16, 16]           5,184
# AdaptiveAvgPool2d-523             [-1, 12, 1, 1]               0
#           Linear-524                    [-1, 0]               0
#             ReLU-525                    [-1, 0]               0
#           Linear-526                   [-1, 12]               0
#          Sigmoid-527                   [-1, 12]               0
#          SEBlock-528           [-1, 12, 16, 16]               0
#       Bottleneck-529           [-1, 12, 16, 16]               0
#        Dropout2d-530          [-1, 246, 16, 16]               0
#      BatchNorm2d-531          [-1, 246, 16, 16]             492
#           Conv2d-532           [-1, 48, 16, 16]          11,808
#        Dropout2d-533           [-1, 48, 16, 16]               0
#      BatchNorm2d-534           [-1, 48, 16, 16]              96
#           Conv2d-535           [-1, 12, 16, 16]           5,184
# AdaptiveAvgPool2d-536             [-1, 12, 1, 1]               0
#           Linear-537                    [-1, 0]               0
#             ReLU-538                    [-1, 0]               0
#           Linear-539                   [-1, 12]               0
#          Sigmoid-540                   [-1, 12]               0
#          SEBlock-541           [-1, 12, 16, 16]               0
#       Bottleneck-542           [-1, 12, 16, 16]               0
#        Dropout2d-543          [-1, 258, 16, 16]               0
#      BatchNorm2d-544          [-1, 258, 16, 16]             516
#           Conv2d-545           [-1, 48, 16, 16]          12,384
#        Dropout2d-546           [-1, 48, 16, 16]               0
#      BatchNorm2d-547           [-1, 48, 16, 16]              96
#           Conv2d-548           [-1, 12, 16, 16]           5,184
# AdaptiveAvgPool2d-549             [-1, 12, 1, 1]               0
#           Linear-550                    [-1, 0]               0
#             ReLU-551                    [-1, 0]               0
#           Linear-552                   [-1, 12]               0
#          Sigmoid-553                   [-1, 12]               0
#          SEBlock-554           [-1, 12, 16, 16]               0
#       Bottleneck-555           [-1, 12, 16, 16]               0
#        Dropout2d-556          [-1, 270, 16, 16]               0
#      BatchNorm2d-557          [-1, 270, 16, 16]             540
#           Conv2d-558           [-1, 48, 16, 16]          12,960
#        Dropout2d-559           [-1, 48, 16, 16]               0
#      BatchNorm2d-560           [-1, 48, 16, 16]              96
#           Conv2d-561           [-1, 12, 16, 16]           5,184
# AdaptiveAvgPool2d-562             [-1, 12, 1, 1]               0
#           Linear-563                    [-1, 0]               0
#             ReLU-564                    [-1, 0]               0
#           Linear-565                   [-1, 12]               0
#          Sigmoid-566                   [-1, 12]               0
#          SEBlock-567           [-1, 12, 16, 16]               0
#       Bottleneck-568           [-1, 12, 16, 16]               0
#        Dropout2d-569          [-1, 282, 16, 16]               0
#      BatchNorm2d-570          [-1, 282, 16, 16]             564
#           Conv2d-571           [-1, 48, 16, 16]          13,536
#        Dropout2d-572           [-1, 48, 16, 16]               0
#      BatchNorm2d-573           [-1, 48, 16, 16]              96
#           Conv2d-574           [-1, 12, 16, 16]           5,184
# AdaptiveAvgPool2d-575             [-1, 12, 1, 1]               0
#           Linear-576                    [-1, 0]               0
#             ReLU-577                    [-1, 0]               0
#           Linear-578                   [-1, 12]               0
#          Sigmoid-579                   [-1, 12]               0
#          SEBlock-580           [-1, 12, 16, 16]               0
#       Bottleneck-581           [-1, 12, 16, 16]               0
#        Dropout2d-582          [-1, 294, 16, 16]               0
#      BatchNorm2d-583          [-1, 294, 16, 16]             588
#           Conv2d-584           [-1, 48, 16, 16]          14,112
#        Dropout2d-585           [-1, 48, 16, 16]               0
#      BatchNorm2d-586           [-1, 48, 16, 16]              96
#           Conv2d-587           [-1, 12, 16, 16]           5,184
# AdaptiveAvgPool2d-588             [-1, 12, 1, 1]               0
#           Linear-589                    [-1, 0]               0
#             ReLU-590                    [-1, 0]               0
#           Linear-591                   [-1, 12]               0
#          Sigmoid-592                   [-1, 12]               0
#          SEBlock-593           [-1, 12, 16, 16]               0
#       Bottleneck-594           [-1, 12, 16, 16]               0
#        Dropout2d-595          [-1, 306, 16, 16]               0
#      BatchNorm2d-596          [-1, 306, 16, 16]             612
#           Conv2d-597           [-1, 48, 16, 16]          14,688
#        Dropout2d-598           [-1, 48, 16, 16]               0
#      BatchNorm2d-599           [-1, 48, 16, 16]              96
#           Conv2d-600           [-1, 12, 16, 16]           5,184
# AdaptiveAvgPool2d-601             [-1, 12, 1, 1]               0
#           Linear-602                    [-1, 0]               0
#             ReLU-603                    [-1, 0]               0
#           Linear-604                   [-1, 12]               0
#          Sigmoid-605                   [-1, 12]               0
#          SEBlock-606           [-1, 12, 16, 16]               0
#       Bottleneck-607           [-1, 12, 16, 16]               0
#        Dropout2d-608          [-1, 318, 16, 16]               0
#      BatchNorm2d-609          [-1, 318, 16, 16]             636
#           Conv2d-610           [-1, 48, 16, 16]          15,264
#        Dropout2d-611           [-1, 48, 16, 16]               0
#      BatchNorm2d-612           [-1, 48, 16, 16]              96
#           Conv2d-613           [-1, 12, 16, 16]           5,184
# AdaptiveAvgPool2d-614             [-1, 12, 1, 1]               0
#           Linear-615                    [-1, 0]               0
#             ReLU-616                    [-1, 0]               0
#           Linear-617                   [-1, 12]               0
#          Sigmoid-618                   [-1, 12]               0
#          SEBlock-619           [-1, 12, 16, 16]               0
#       Bottleneck-620           [-1, 12, 16, 16]               0
#        Dropout2d-621          [-1, 330, 16, 16]               0
#      BatchNorm2d-622          [-1, 330, 16, 16]             660
#           Conv2d-623           [-1, 48, 16, 16]          15,840
#        Dropout2d-624           [-1, 48, 16, 16]               0
#      BatchNorm2d-625           [-1, 48, 16, 16]              96
#           Conv2d-626           [-1, 12, 16, 16]           5,184
# AdaptiveAvgPool2d-627             [-1, 12, 1, 1]               0
#           Linear-628                    [-1, 0]               0
#             ReLU-629                    [-1, 0]               0
#           Linear-630                   [-1, 12]               0
#          Sigmoid-631                   [-1, 12]               0
#          SEBlock-632           [-1, 12, 16, 16]               0
#       Bottleneck-633           [-1, 12, 16, 16]               0
#       DenseBlock-634          [-1, 342, 16, 16]               0
#      BatchNorm2d-635          [-1, 342, 16, 16]             684
# AdaptiveAvgPool2d-636            [-1, 342, 1, 1]               0
#          Flatten-637                  [-1, 342]               0
#           Linear-638                  [-1, 200]          68,600
# ================================================================
# Total params: 834,332
# Trainable params: 834,332
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.05
# Forward/backward pass size (MB): 322.60
# Params size (MB): 3.18
# Estimated Total Size (MB): 325.83
# ----------------------------------------------------------------
# c:\Users\NguyenThanh\anaconda3\envs\ml-classification\Lib\site-packages\torch\nn\init.py:511: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")

# %%
x = torch.rand((64, 3, 64, 64)).to(device)      # Test the Net
net(x).shape
# Out:
# torch.Size([64, 200])

# %%
def evaluate(net: nn.Module,
             data_loader: torch.utils.data.DataLoader) -> float:
  
    correct = 0
    total = 0
    net.eval()
    with torch.no_grad():
        with tqdm(total=len(data_loader), leave=True, desc=f"Evaluating progress: ", ncols=100) as pbar:
            for batch_idx, (inputs, targets) in enumerate(data_loader):
                inputs, targets = inputs.to(device), targets.to(device)
                pred_target = net(inputs).argmax(dim=1)
                correct += (pred_target == targets).sum().item()
                total += targets.size(0)
                pbar.update(1)

    return correct / total

# %%
def train(train_data,
          val_data,
          net,
          **kwargs):
          
    start_time = time.time()
    torch.cuda.reset_peak_memory_stats()

    train_losses = []
    train_accuracies = []
    val_losses = []
    val_accuracies = []

    

    train_loader = torch.utils.data.DataLoader(train_data,
                                                batch_size=kwargs['batch_size'],
                                                shuffle=True, num_workers=0, pin_memory=False)
    
    val_loader = torch.utils.data.DataLoader(val_data,
                                                batch_size=kwargs['batch_size'],
                                                shuffle=False, num_workers=0, pin_memory=False)
  
    optimizer = opt.SGD(net.parameters(), lr=kwargs['lr'], momentum=0.9, weight_decay=1e-4, nesterov=True)
    scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[90, 135], gamma=0.1)
    criterion = nn.CrossEntropyLoss()
    scaler = torch.GradScaler(device="cuda")
    best_val_loss = 10
    best_epoch = 0 

    for epoch in range(kwargs['epochs']):
        net.train()
        train_loss = 0
        with tqdm(total=len(train_loader), leave=True, desc=f"Epoch {epoch+1}/{kwargs['epochs']}", ncols=100) as pbar:
            for batch_idx, (inputs, targets) in enumerate(train_loader):
                inputs, targets = inputs.to(device), targets.to(device)
                optimizer.zero_grad()
                with torch.autocast(device_type="cuda"):
                    pred_targets = net(inputs)
                    loss = criterion(pred_targets, targets)
                scaler.scale(loss).backward()
                scaler.step(optimizer)
                scaler.update()
                train_loss += loss.item()
                pbar.update(1)

        train_loss /= len(train_loader)
        train_losses.append(train_loss)

        net.eval()
        val_loss = 0
        with torch.no_grad():
            for inputs, targets in val_loader:
                inputs, targets = inputs.to(device), targets.to(device)
                with torch.autocast(device_type="cuda"):
                    pred_targets = net(inputs)
                    loss = criterion(pred_targets, targets)
                val_loss += loss.item()
        val_loss /= len(val_loader)
        val_losses.append(val_loss)

        scheduler.step()

     
        train_accuracy = evaluate(net, train_loader)
        train_accuracies.append(train_accuracy)
        
        val_accuracy = evaluate(net, val_loader)
        val_accuracies.append(val_accuracy)

        logging.info(f"Epoch {epoch+1}, Train Loss: {train_loss:.4f}, Train Acc: {train_accuracy:.4f}, Val Loss: {val_loss:.4f} Val Acc: {val_accuracy:.4f}")

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_epoch = epoch
            torch.save(net.state_dict(), "best_model.pth")
            logging.info("Saved best model.")

    end_time = time.time()
    total_time = end_time - start_time
    peak_memory = torch.cuda.max_memory_allocated() / (1024 ** 2)  # MB

    print(f"Total training time: {total_time:.2f} seconds")
    print(f"Peak GPU memory usage: {peak_memory:.2f} MB")

    return net, train_losses, val_losses, train_accuracies, val_accuracies, best_epoch

# %%
lr = 0.1
batch_size = 64
epochs = 180
net, train_losses, val_losses, train_accuracies, val_accuracies, best_epoch = train(train_data=tinyimagenet_train,
                                            val_data=tinyimagenet_val,
                                            net=net,
                                            lr=lr,
                                            batch_size=batch_size,
                                            epochs=epochs)
# Out:
# Epoch 1/180: 100%|██████████████████████████████████████████████| 1407/1407 [01:57<00:00, 11.95it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:53<00:00, 26.36it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 27.62it/s]
# Epoch 2/180: 100%|██████████████████████████████████████████████| 1407/1407 [01:58<00:00, 11.89it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:01<00:00, 22.84it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 24.72it/s]
# Epoch 3/180: 100%|██████████████████████████████████████████████| 1407/1407 [02:37<00:00,  8.91it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:01<00:00, 22.86it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 24.69it/s]
# Epoch 4/180: 100%|██████████████████████████████████████████████| 1407/1407 [02:39<00:00,  8.85it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:01<00:00, 22.81it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 24.65it/s]
# Epoch 5/180: 100%|██████████████████████████████████████████████| 1407/1407 [02:38<00:00,  8.86it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:01<00:00, 22.78it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 24.65it/s]
# Epoch 6/180: 100%|██████████████████████████████████████████████| 1407/1407 [02:26<00:00,  9.58it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:56<00:00, 24.95it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 25.93it/s]
# Epoch 7/180: 100%|██████████████████████████████████████████████| 1407/1407 [01:56<00:00, 12.13it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:54<00:00, 25.96it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 28.24it/s]
# Epoch 8/180: 100%|██████████████████████████████████████████████| 1407/1407 [01:49<00:00, 12.89it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:51<00:00, 27.07it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 28.30it/s]
# Epoch 9/180: 100%|██████████████████████████████████████████████| 1407/1407 [01:48<00:00, 12.96it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:51<00:00, 27.07it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 28.33it/s]
# Epoch 10/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:48<00:00, 13.01it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:51<00:00, 27.07it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 28.37it/s]
# Epoch 11/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:48<00:00, 12.96it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:52<00:00, 27.04it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 28.33it/s]
# Epoch 12/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:46<00:00, 13.22it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:52<00:00, 27.02it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 28.32it/s]
# Epoch 13/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:47<00:00, 13.03it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:52<00:00, 27.02it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 28.31it/s]
# Epoch 14/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:48<00:00, 12.97it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:52<00:00, 27.00it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 28.31it/s]
# Epoch 15/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:47<00:00, 13.05it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:52<00:00, 27.00it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 28.24it/s]
# Epoch 16/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:47<00:00, 13.07it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:52<00:00, 26.95it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 28.22it/s]
# Epoch 17/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:48<00:00, 13.01it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:52<00:00, 26.96it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 28.24it/s]
# Epoch 18/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:48<00:00, 12.96it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:52<00:00, 26.97it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 28.18it/s]
# Epoch 19/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:48<00:00, 12.99it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:52<00:00, 26.93it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 28.19it/s]
# Epoch 20/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:51<00:00, 12.66it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:53<00:00, 26.25it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 27.45it/s]
# Epoch 21/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:50<00:00, 12.78it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:53<00:00, 26.23it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 27.46it/s]
# Epoch 22/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:52<00:00, 12.48it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:53<00:00, 26.27it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 27.48it/s]
# Epoch 23/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:52<00:00, 12.47it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:53<00:00, 26.25it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 27.42it/s]
# Epoch 24/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:50<00:00, 12.76it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:53<00:00, 26.09it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 24.41it/s]
# Epoch 25/180: 100%|█████████████████████████████████████████████| 1407/1407 [02:40<00:00,  8.76it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:02<00:00, 22.59it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 24.38it/s]
# Epoch 26/180: 100%|█████████████████████████████████████████████| 1407/1407 [02:40<00:00,  8.76it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:01<00:00, 23.00it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 24.41it/s]
# Epoch 27/180: 100%|█████████████████████████████████████████████| 1407/1407 [02:40<00:00,  8.75it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:02<00:00, 22.56it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 24.39it/s]
# Epoch 28/180: 100%|█████████████████████████████████████████████| 1407/1407 [02:40<00:00,  8.75it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:02<00:00, 22.55it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 24.37it/s]
# Epoch 29/180: 100%|█████████████████████████████████████████████| 1407/1407 [02:06<00:00, 11.16it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:52<00:00, 26.69it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 27.93it/s]
# Epoch 30/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:48<00:00, 12.93it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:52<00:00, 26.70it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 27.93it/s]
# Epoch 31/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:48<00:00, 12.97it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:52<00:00, 26.55it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 27.78it/s]
# Epoch 32/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:49<00:00, 12.89it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:52<00:00, 26.86it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 28.11it/s]
# Epoch 33/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:48<00:00, 12.94it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:52<00:00, 26.85it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 28.05it/s]
# Epoch 34/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:49<00:00, 12.90it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:52<00:00, 26.83it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 28.13it/s]
# Epoch 35/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:49<00:00, 12.82it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:52<00:00, 26.84it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 28.08it/s]
# Epoch 36/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:48<00:00, 12.91it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:52<00:00, 26.83it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 28.08it/s]
# Epoch 37/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:49<00:00, 12.88it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:52<00:00, 26.80it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 28.09it/s]
# Epoch 38/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:51<00:00, 12.66it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:52<00:00, 26.78it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 27.95it/s]
# Epoch 39/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:49<00:00, 12.88it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:52<00:00, 26.79it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 28.06it/s]
# Epoch 40/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:49<00:00, 12.89it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:52<00:00, 26.76it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 28.02it/s]
# Epoch 41/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:49<00:00, 12.88it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:52<00:00, 26.76it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 27.99it/s]
# Epoch 42/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:49<00:00, 12.88it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:53<00:00, 26.42it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 27.82it/s]
# Epoch 43/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:49<00:00, 12.83it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:52<00:00, 26.56it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 27.79it/s]
# Epoch 44/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:50<00:00, 12.69it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:52<00:00, 26.55it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 27.79it/s]
# Epoch 45/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:49<00:00, 12.89it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:52<00:00, 26.57it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 27.78it/s]
# Epoch 46/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:50<00:00, 12.78it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:53<00:00, 26.52it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 27.73it/s]
# Epoch 47/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:50<00:00, 12.76it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:53<00:00, 26.52it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 27.75it/s]
# Epoch 48/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:50<00:00, 12.68it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:53<00:00, 26.52it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 27.74it/s]
# Epoch 49/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:49<00:00, 12.83it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:53<00:00, 26.49it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 27.73it/s]
# Epoch 50/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:49<00:00, 12.81it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:53<00:00, 26.49it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 27.75it/s]
# Epoch 51/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:50<00:00, 12.75it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:53<00:00, 26.48it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 27.73it/s]
# Epoch 52/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:50<00:00, 12.76it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:53<00:00, 26.48it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 27.70it/s]
# Epoch 53/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:49<00:00, 12.80it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:53<00:00, 26.42it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 27.62it/s]
# Epoch 54/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:50<00:00, 12.76it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:53<00:00, 26.42it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 27.66it/s]
# Epoch 55/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:50<00:00, 12.79it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:53<00:00, 26.42it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 27.65it/s]
# Epoch 56/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:50<00:00, 12.79it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:53<00:00, 26.38it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 27.61it/s]
# Epoch 57/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:49<00:00, 12.87it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:53<00:00, 26.40it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 27.68it/s]
# Epoch 58/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:49<00:00, 12.90it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:53<00:00, 26.39it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 27.65it/s]
# Epoch 59/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:50<00:00, 12.78it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:54<00:00, 25.87it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 27.07it/s]
# Epoch 60/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:51<00:00, 12.67it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:54<00:00, 25.84it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 27.08it/s]
# Epoch 61/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:52<00:00, 12.55it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:54<00:00, 25.85it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 27.02it/s]
# Epoch 62/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:51<00:00, 12.61it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:54<00:00, 25.82it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 27.05it/s]
# Epoch 63/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:50<00:00, 12.70it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:54<00:00, 25.84it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 26.96it/s]
# Epoch 64/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:51<00:00, 12.67it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:54<00:00, 25.79it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 27.02it/s]
# Epoch 65/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:50<00:00, 12.71it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:54<00:00, 25.81it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 27.01it/s]
# Epoch 66/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:51<00:00, 12.62it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:54<00:00, 25.78it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 27.00it/s]
# Epoch 67/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:51<00:00, 12.62it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:54<00:00, 25.79it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 26.95it/s]
# Epoch 68/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:52<00:00, 12.49it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:54<00:00, 25.79it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 26.95it/s]
# Epoch 69/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:52<00:00, 12.49it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:54<00:00, 25.77it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 26.99it/s]
# Epoch 70/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:52<00:00, 12.49it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:54<00:00, 25.75it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 26.94it/s]
# Epoch 71/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:52<00:00, 12.50it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:54<00:00, 25.77it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 26.94it/s]
# Epoch 72/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:51<00:00, 12.61it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:54<00:00, 25.73it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 26.92it/s]
# Epoch 73/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:52<00:00, 12.51it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:54<00:00, 25.70it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 26.89it/s]
# Epoch 74/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:50<00:00, 12.69it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:54<00:00, 25.73it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 26.89it/s]
# Epoch 75/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:52<00:00, 12.46it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:54<00:00, 25.71it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 26.88it/s]
# Epoch 76/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:53<00:00, 12.44it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:54<00:00, 25.69it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 26.87it/s]
# Epoch 77/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:51<00:00, 12.62it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:54<00:00, 25.68it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 26.82it/s]
# Epoch 78/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:51<00:00, 12.61it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:54<00:00, 25.67it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 26.87it/s]
# Epoch 79/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:50<00:00, 12.73it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:54<00:00, 25.68it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 26.88it/s]
# Epoch 80/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:52<00:00, 12.54it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:54<00:00, 25.90it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 27.42it/s]
# Epoch 81/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:50<00:00, 12.69it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:53<00:00, 26.11it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 27.38it/s]
# Epoch 82/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:50<00:00, 12.70it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:53<00:00, 26.12it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 27.34it/s]
# Epoch 83/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:51<00:00, 12.67it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:53<00:00, 26.12it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 27.32it/s]
# Epoch 84/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:50<00:00, 12.78it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:53<00:00, 26.12it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 27.28it/s]
# Epoch 85/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:51<00:00, 12.66it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:01<00:00, 22.94it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 23.69it/s]
# Epoch 86/180: 100%|█████████████████████████████████████████████| 1407/1407 [02:46<00:00,  8.45it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:04<00:00, 21.91it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 23.68it/s]
# Epoch 87/180: 100%|█████████████████████████████████████████████| 1407/1407 [02:37<00:00,  8.92it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:58<00:00, 24.14it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 24.29it/s]
# Epoch 88/180: 100%|█████████████████████████████████████████████| 1407/1407 [02:09<00:00, 10.90it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:59<00:00, 23.65it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 24.04it/s]
# Epoch 89/180: 100%|█████████████████████████████████████████████| 1407/1407 [02:36<00:00,  9.00it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:04<00:00, 21.89it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 23.70it/s]
# Epoch 90/180: 100%|█████████████████████████████████████████████| 1407/1407 [02:47<00:00,  8.42it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:04<00:00, 21.89it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 23.62it/s]
# Epoch 91/180: 100%|█████████████████████████████████████████████| 1407/1407 [02:47<00:00,  8.42it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:04<00:00, 21.85it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 23.60it/s]
# Epoch 92/180: 100%|█████████████████████████████████████████████| 1407/1407 [02:47<00:00,  8.40it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:04<00:00, 21.88it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 23.62it/s]
# Epoch 93/180: 100%|█████████████████████████████████████████████| 1407/1407 [02:47<00:00,  8.42it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:04<00:00, 21.86it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 23.57it/s]
# Epoch 94/180: 100%|█████████████████████████████████████████████| 1407/1407 [02:45<00:00,  8.51it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:02<00:00, 22.48it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 23.57it/s]
# Epoch 95/180: 100%|█████████████████████████████████████████████| 1407/1407 [02:47<00:00,  8.42it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:04<00:00, 21.84it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 23.57it/s]
# Epoch 96/180: 100%|█████████████████████████████████████████████| 1407/1407 [02:41<00:00,  8.69it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:04<00:00, 21.80it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 23.54it/s]
# Epoch 97/180: 100%|█████████████████████████████████████████████| 1407/1407 [02:45<00:00,  8.48it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:04<00:00, 21.79it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 23.51it/s]
# Epoch 98/180: 100%|█████████████████████████████████████████████| 1407/1407 [02:44<00:00,  8.57it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:53<00:00, 26.10it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 27.32it/s]
# Epoch 99/180: 100%|█████████████████████████████████████████████| 1407/1407 [01:51<00:00, 12.63it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:54<00:00, 25.67it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 26.34it/s]
# Epoch 100/180: 100%|████████████████████████████████████████████| 1407/1407 [02:45<00:00,  8.50it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:55<00:00, 25.29it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 26.77it/s]
# Epoch 101/180: 100%|████████████████████████████████████████████| 1407/1407 [01:51<00:00, 12.66it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:55<00:00, 25.54it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 26.88it/s]
# Epoch 102/180: 100%|████████████████████████████████████████████| 1407/1407 [01:51<00:00, 12.59it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:55<00:00, 25.47it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 25.47it/s]
# Epoch 103/180: 100%|████████████████████████████████████████████| 1407/1407 [02:43<00:00,  8.62it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:04<00:00, 21.94it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 23.08it/s]
# Epoch 104/180: 100%|████████████████████████████████████████████| 1407/1407 [02:45<00:00,  8.48it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:05<00:00, 21.32it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 22.90it/s]
# Epoch 105/180: 100%|████████████████████████████████████████████| 1407/1407 [02:45<00:00,  8.48it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:05<00:00, 21.32it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 23.02it/s]
# Epoch 106/180: 100%|████████████████████████████████████████████| 1407/1407 [02:47<00:00,  8.42it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:05<00:00, 21.32it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 23.00it/s]
# Epoch 107/180: 100%|████████████████████████████████████████████| 1407/1407 [02:47<00:00,  8.42it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:06<00:00, 21.27it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 22.95it/s]
# Epoch 108/180: 100%|████████████████████████████████████████████| 1407/1407 [02:35<00:00,  9.06it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:05<00:00, 21.35it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 22.96it/s]
# Epoch 109/180: 100%|████████████████████████████████████████████| 1407/1407 [02:49<00:00,  8.32it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:06<00:00, 21.28it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 22.95it/s]
# Epoch 110/180: 100%|████████████████████████████████████████████| 1407/1407 [02:41<00:00,  8.71it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:04<00:00, 21.82it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 22.92it/s]
# Epoch 111/180: 100%|████████████████████████████████████████████| 1407/1407 [02:53<00:00,  8.10it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:06<00:00, 21.21it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 22.94it/s]
# Epoch 112/180: 100%|████████████████████████████████████████████| 1407/1407 [02:47<00:00,  8.38it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:05<00:00, 21.60it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 22.81it/s]
# Epoch 113/180: 100%|████████████████████████████████████████████| 1407/1407 [02:54<00:00,  8.09it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:06<00:00, 21.13it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 22.89it/s]
# Epoch 114/180: 100%|████████████████████████████████████████████| 1407/1407 [02:42<00:00,  8.66it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:05<00:00, 21.44it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 22.77it/s]
# Epoch 115/180: 100%|████████████████████████████████████████████| 1407/1407 [02:33<00:00,  9.14it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:55<00:00, 25.21it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 26.25it/s]
# Epoch 116/180: 100%|████████████████████████████████████████████| 1407/1407 [02:04<00:00, 11.26it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:06<00:00, 21.15it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 22.56it/s]
# Epoch 117/180: 100%|████████████████████████████████████████████| 1407/1407 [02:50<00:00,  8.26it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:05<00:00, 21.56it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 22.65it/s]
# Epoch 118/180: 100%|████████████████████████████████████████████| 1407/1407 [02:50<00:00,  8.25it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:06<00:00, 21.09it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 22.63it/s]
# Epoch 119/180: 100%|████████████████████████████████████████████| 1407/1407 [02:55<00:00,  8.03it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:06<00:00, 21.09it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 22.75it/s]
# Epoch 120/180: 100%|████████████████████████████████████████████| 1407/1407 [02:49<00:00,  8.29it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:06<00:00, 21.05it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 22.79it/s]
# Epoch 121/180: 100%|████████████████████████████████████████████| 1407/1407 [02:47<00:00,  8.42it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:05<00:00, 21.51it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 22.76it/s]
# Epoch 122/180: 100%|████████████████████████████████████████████| 1407/1407 [02:50<00:00,  8.23it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:07<00:00, 20.98it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 22.70it/s]
# Epoch 123/180: 100%|████████████████████████████████████████████| 1407/1407 [02:56<00:00,  7.99it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:05<00:00, 21.53it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 22.59it/s]
# Epoch 124/180: 100%|████████████████████████████████████████████| 1407/1407 [02:56<00:00,  7.98it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:07<00:00, 20.93it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:07<00:00, 22.40it/s]
# Epoch 125/180: 100%|████████████████████████████████████████████| 1407/1407 [02:40<00:00,  8.74it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:05<00:00, 21.40it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:07<00:00, 22.34it/s]
# Epoch 126/180: 100%|████████████████████████████████████████████| 1407/1407 [02:32<00:00,  9.23it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:54<00:00, 25.58it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 26.66it/s]
# Epoch 127/180: 100%|████████████████████████████████████████████| 1407/1407 [01:50<00:00, 12.73it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:54<00:00, 25.59it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 26.66it/s]
# Epoch 128/180: 100%|████████████████████████████████████████████| 1407/1407 [01:50<00:00, 12.73it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:55<00:00, 25.54it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 26.76it/s]
# Epoch 129/180: 100%|████████████████████████████████████████████| 1407/1407 [01:53<00:00, 12.41it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:57<00:00, 24.49it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 25.64it/s]
# Epoch 130/180: 100%|████████████████████████████████████████████| 1407/1407 [01:54<00:00, 12.29it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:57<00:00, 24.43it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 25.68it/s]
# Epoch 131/180: 100%|████████████████████████████████████████████| 1407/1407 [01:54<00:00, 12.29it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:57<00:00, 24.43it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 25.66it/s]
# Epoch 132/180: 100%|████████████████████████████████████████████| 1407/1407 [01:54<00:00, 12.26it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:05<00:00, 21.39it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 22.62it/s]
# Epoch 133/180: 100%|████████████████████████████████████████████| 1407/1407 [02:56<00:00,  7.97it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:05<00:00, 21.38it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 22.52it/s]
# Epoch 134/180: 100%|████████████████████████████████████████████| 1407/1407 [02:56<00:00,  7.97it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:06<00:00, 21.31it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 24.09it/s]
# Epoch 135/180: 100%|████████████████████████████████████████████| 1407/1407 [02:33<00:00,  9.17it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:07<00:00, 20.80it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:07<00:00, 22.27it/s]
# Epoch 136/180: 100%|████████████████████████████████████████████| 1407/1407 [02:51<00:00,  8.21it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:02<00:00, 22.56it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 24.38it/s]
# Epoch 137/180: 100%|████████████████████████████████████████████| 1407/1407 [01:59<00:00, 11.82it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:56<00:00, 24.91it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 26.29it/s]
# Epoch 138/180: 100%|████████████████████████████████████████████| 1407/1407 [01:53<00:00, 12.35it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:56<00:00, 25.11it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 26.18it/s]
# Epoch 139/180: 100%|████████████████████████████████████████████| 1407/1407 [02:02<00:00, 11.48it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:58<00:00, 24.22it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 25.15it/s]
# Epoch 140/180: 100%|████████████████████████████████████████████| 1407/1407 [01:55<00:00, 12.19it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:58<00:00, 24.18it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 25.13it/s]
# Epoch 141/180: 100%|████████████████████████████████████████████| 1407/1407 [01:55<00:00, 12.17it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:58<00:00, 24.19it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 25.31it/s]
# Epoch 142/180: 100%|████████████████████████████████████████████| 1407/1407 [01:55<00:00, 12.19it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:58<00:00, 24.22it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 25.18it/s]
# Epoch 143/180: 100%|████████████████████████████████████████████| 1407/1407 [01:55<00:00, 12.18it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:58<00:00, 24.23it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 25.16it/s]
# Epoch 144/180: 100%|████████████████████████████████████████████| 1407/1407 [01:54<00:00, 12.33it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:56<00:00, 25.09it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 26.02it/s]
# Epoch 145/180: 100%|████████████████████████████████████████████| 1407/1407 [01:54<00:00, 12.34it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:56<00:00, 24.87it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 26.07it/s]
# Epoch 146/180: 100%|████████████████████████████████████████████| 1407/1407 [01:53<00:00, 12.44it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:56<00:00, 24.91it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 26.11it/s]
# Epoch 147/180: 100%|████████████████████████████████████████████| 1407/1407 [01:53<00:00, 12.35it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:56<00:00, 24.89it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 26.00it/s]
# Epoch 148/180: 100%|████████████████████████████████████████████| 1407/1407 [01:53<00:00, 12.37it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:56<00:00, 24.77it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 26.00it/s]
# Epoch 149/180: 100%|████████████████████████████████████████████| 1407/1407 [02:17<00:00, 10.22it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:11<00:00, 19.56it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:07<00:00, 22.06it/s]
# Epoch 150/180: 100%|████████████████████████████████████████████| 1407/1407 [03:00<00:00,  7.81it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:11<00:00, 19.79it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 22.79it/s]
# Epoch 151/180: 100%|████████████████████████████████████████████| 1407/1407 [02:54<00:00,  8.07it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:10<00:00, 19.86it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:07<00:00, 22.26it/s]
# Epoch 152/180: 100%|████████████████████████████████████████████| 1407/1407 [02:59<00:00,  7.84it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:11<00:00, 19.56it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:07<00:00, 22.19it/s]
# Epoch 153/180: 100%|████████████████████████████████████████████| 1407/1407 [02:59<00:00,  7.83it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:10<00:00, 20.00it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:07<00:00, 22.20it/s]
# Epoch 154/180: 100%|████████████████████████████████████████████| 1407/1407 [02:59<00:00,  7.86it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:10<00:00, 19.90it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:07<00:00, 22.23it/s]
# Epoch 155/180: 100%|████████████████████████████████████████████| 1407/1407 [02:02<00:00, 11.48it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:56<00:00, 24.96it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:05<00:00, 26.21it/s]
# Epoch 156/180: 100%|████████████████████████████████████████████| 1407/1407 [01:52<00:00, 12.46it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:56<00:00, 24.94it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 25.86it/s]
# Epoch 157/180: 100%|████████████████████████████████████████████| 1407/1407 [01:52<00:00, 12.48it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:56<00:00, 24.90it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 25.98it/s]
# Epoch 158/180: 100%|████████████████████████████████████████████| 1407/1407 [01:52<00:00, 12.48it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:02<00:00, 22.55it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:07<00:00, 22.13it/s]
# Epoch 159/180: 100%|████████████████████████████████████████████| 1407/1407 [03:00<00:00,  7.81it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:11<00:00, 19.61it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:07<00:00, 22.21it/s]
# Epoch 160/180: 100%|████████████████████████████████████████████| 1407/1407 [03:00<00:00,  7.79it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:11<00:00, 19.80it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:07<00:00, 21.99it/s]
# Epoch 161/180: 100%|████████████████████████████████████████████| 1407/1407 [02:12<00:00, 10.62it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:58<00:00, 24.10it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 25.18it/s]
# Epoch 162/180: 100%|████████████████████████████████████████████| 1407/1407 [01:55<00:00, 12.13it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:58<00:00, 24.10it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 25.09it/s]
# Epoch 163/180: 100%|████████████████████████████████████████████| 1407/1407 [01:56<00:00, 12.12it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:58<00:00, 24.05it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 25.07it/s]
# Epoch 164/180: 100%|████████████████████████████████████████████| 1407/1407 [01:56<00:00, 12.04it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:58<00:00, 24.05it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 25.22it/s]
# Epoch 165/180: 100%|████████████████████████████████████████████| 1407/1407 [01:56<00:00, 12.06it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:57<00:00, 24.40it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 25.49it/s]
# Epoch 166/180: 100%|████████████████████████████████████████████| 1407/1407 [01:55<00:00, 12.14it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:57<00:00, 24.41it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 25.45it/s]
# Epoch 167/180: 100%|████████████████████████████████████████████| 1407/1407 [01:56<00:00, 12.11it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:57<00:00, 24.38it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 25.50it/s]
# Epoch 168/180: 100%|████████████████████████████████████████████| 1407/1407 [01:55<00:00, 12.21it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:57<00:00, 24.35it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 25.36it/s]
# Epoch 169/180: 100%|████████████████████████████████████████████| 1407/1407 [01:55<00:00, 12.20it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:58<00:00, 24.08it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 25.56it/s]
# Epoch 170/180: 100%|████████████████████████████████████████████| 1407/1407 [01:54<00:00, 12.24it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:57<00:00, 24.39it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 25.55it/s]
# Epoch 171/180: 100%|████████████████████████████████████████████| 1407/1407 [01:55<00:00, 12.21it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:57<00:00, 24.43it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 25.48it/s]
# Epoch 172/180: 100%|████████████████████████████████████████████| 1407/1407 [01:55<00:00, 12.22it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:57<00:00, 24.39it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 25.47it/s]
# Epoch 173/180: 100%|████████████████████████████████████████████| 1407/1407 [01:54<00:00, 12.24it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:58<00:00, 24.01it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 25.33it/s]
# Epoch 174/180: 100%|████████████████████████████████████████████| 1407/1407 [01:55<00:00, 12.17it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:57<00:00, 24.31it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 25.27it/s]
# Epoch 175/180: 100%|████████████████████████████████████████████| 1407/1407 [01:54<00:00, 12.24it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:58<00:00, 24.26it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 25.31it/s]
# Epoch 176/180: 100%|████████████████████████████████████████████| 1407/1407 [01:55<00:00, 12.18it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:57<00:00, 24.28it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 25.27it/s]
# Epoch 177/180: 100%|████████████████████████████████████████████| 1407/1407 [01:55<00:00, 12.20it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:58<00:00, 24.24it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 25.22it/s]
# Epoch 178/180: 100%|████████████████████████████████████████████| 1407/1407 [01:55<00:00, 12.21it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:58<00:00, 24.20it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 25.25it/s]
# Epoch 179/180: 100%|████████████████████████████████████████████| 1407/1407 [01:55<00:00, 12.16it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [00:57<00:00, 24.48it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 25.81it/s]
# Epoch 180/180: 100%|████████████████████████████████████████████| 1407/1407 [02:01<00:00, 11.55it/s]
# Evaluating progress: 100%|██████████████████████████████████████| 1407/1407 [01:01<00:00, 23.06it/s]
# Evaluating progress: 100%|████████████████████████████████████████| 157/157 [00:06<00:00, 23.86it/s]
# Total training time: 35622.74 seconds
# Peak GPU memory usage: 2144.01 MB

# %%
plt.plot(train_losses, label='Train Loss', c="blue")
plt.plot(val_losses, label='Validation Loss', c="red")
plt.axvline(x=best_epoch, color='green', linestyle='--', label=f'Best Epoch ({best_epoch})')
plt.title('Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.plot(train_accuracies, label='Train Accuracy', c="blue")
plt.plot(val_accuracies, label='Validation Accuracy', c="red")
plt.axvline(x=best_epoch, color='green', linestyle='--', label=f'Best Epoch ({best_epoch})')
plt.title('Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
test_loader = torch.utils.data.DataLoader(tinyimagenet_test,
                                                batch_size=100,
                                                shuffle=False, num_workers=0, pin_memory=False)

# %%
net.load_state_dict(torch.load("best_model.pth"))
net.to(device)
net.eval()
test_accuracy = evaluate(net, test_loader)
print(f"Test accuracy: {test_accuracy:.4f}")
# Out:
# Evaluating progress: 100%|████████████████████████████████████████| 100/100 [00:05<00:00, 17.02it/s]
# Test accuracy: 0.5439
